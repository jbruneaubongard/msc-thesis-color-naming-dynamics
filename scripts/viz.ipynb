# %%
from src.visualization import *

# %% [markdown]
# ## Plotting the trajectories

# %%
dataset = 'shuffled_voronoi' # Choose the desired dataset
mode = 'NIL' # Choose the desired mode
index = 0 # Choose the desired index

plot_trajectory(dataset, mode, index, save=False) # Set save=True to save the figure

# %% [markdown]
# ## Plotting the initial and final languages

# %%
dataset = 'shuffled_voronoi' # Choose the desired dataset
mode = 'NIL' # Choose the desired mode
index = 0 # Choose the desired index

plot_initial_final_palettes(dataset, mode, index, save=False) # Set save=True to save the figure
